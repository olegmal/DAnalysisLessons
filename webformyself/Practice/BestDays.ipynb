# %%
import pandas as pd

# %%
df = pd.read_csv('result.csv')

# %%
df
# Out:
#         Order_Id                     Product  Quantity   Price   Total  \
# 0         176558        USB-C Charging Cable         2   11.95   23.90
# 1         176559  Bose SoundSport Headphones         1   99.99   99.99
# 2         176560                Google Phone         1  600.00  600.00
# 3         176560            Wired Headphones         1   11.99   11.99
# 4         176561            Wired Headphones         1   11.99   11.99
# ...          ...                         ...       ...     ...     ...
# 185945    259353      AAA Batteries (4-pack)         3    2.99    8.97
# 185946    259354                      iPhone         1  700.00  700.00
# 185947    259355                      iPhone         1  700.00  700.00
# 185948    259356      34in Ultrawide Monitor         1  379.99  379.99
# 185949    259357        USB-C Charging Cable         1   11.95   11.95
#
#                  Order_Date                                   Adress  Month
# ...

# %%
df['Day_name'] = df.Order_Date.dt.day_name()
df
# Out:
#         Order_Id                     Product  Quantity   Price   Total  \
# 0         176558        USB-C Charging Cable         2   11.95   23.90
# 1         176559  Bose SoundSport Headphones         1   99.99   99.99
# 2         176560                Google Phone         1  600.00  600.00
# 3         176560            Wired Headphones         1   11.99   11.99
# 4         176561            Wired Headphones         1   11.99   11.99
# ...          ...                         ...       ...     ...     ...
# 185945    259353      AAA Batteries (4-pack)         3    2.99    8.97
# 185946    259354                      iPhone         1  700.00  700.00
# 185947    259355                      iPhone         1  700.00  700.00
# 185948    259356      34in Ultrawide Monitor         1  379.99  379.99
# 185949    259357        USB-C Charging Cable         1   11.95   11.95
#
#                 Order_Date                                   Adress  Month  \
# ...

# %%
result = df.groupby('Day_name').agg(['sum', 'count'])['Total']
result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 result = df.groupby('Day_name').agg(['sum', 'count'])
#       2 result
#
# File D:\PythonProject\webformyself\venv\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File D:\PythonProject\webformyself\venv\Lib\site-packages\pandas\core\apply.py:193, in Apply.agg(self)
#     190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
# ...

# %%
res2 = result.sort_values('sum')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 result.sort_values('sum')
#
# NameError: name 'result' is not defined
