# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in d:\pythonproject\webformyself\venv\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\pythonproject\webformyself\venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in d:\pythonproject\webformyself\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\pythonproject\webformyself\venv\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\pythonproject\webformyself\venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in d:\pythonproject\webformyself\venv\lib\site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in d:\pythonproject\webformyself\venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in d:\pythonproject\webformyself\venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\pythonproject\webformyself\venv\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in d:\pythonproject\webformyself\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\pythonproject\webformyself\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.plot([3, 5, 10, 7, 11])

# %%
plt.plot([3, 5, 10, 7, 11], range(1, 6))

# %%
plt.plot([3, 5, 10, 7, 11])
plt.plot([11, 7, 10, 5, 3])

# %%
plt.plot([3, 5, 10, 7, 11])
plt.show()
plt.plot([11, 7, 10, 5, 3])

# %%
df = pd.read_csv("D:/PythonProject/webformyself/Practice/city.csv", sep=';')
df
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
data=df.groupby('CountryCode')[['Population']].sum().sort_values(by='Population', ascending=False).head(10)

# %%
plt.bar(data.index, data.Population)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.barh(data.index, data.Population)
plt.legend(['Population'])

# %%
plt.bar(data.index, data.Population)
plt.legend('Population')
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Top 10 country population ')
plt.grid()

# %%
data.plot(kind='barh', grid=True)
# Out:
# <Axes: ylabel='CountryCode'>

# %%
data.plot(kind='pie', y='Population')
# Out:
# <Axes: ylabel='Population'>

# %%
plt.pie(data.Population, labels=data.index, autopct='%1.1f%%', shadow=True)
plt.legend(data.index, loc='best', bbox_to_anchor=(1, 1))
plt.show()
