# %%
import pandas as pd

# %%
df1= pd.read_csv("D:/PythonProject/webformyself/city.csv",sep=';')
df1
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
df1[df1.CountryCode == 'AFG'].max()
# Out:
# ID                    4
# Name           Qandahar
# CountryCode         AFG
# District       Qandahar
# Population      1780000
# dtype: object

# %%
df1[df1.CountryCode == 'AFG'][['ID', 'Population']].min()
# Out:
# ID                 1
# Population    127800
# dtype: int64

# %%
df1[df1.CountryCode == 'AFG']['Population'].sum()
# Out:
# np.int64(2332100)

# %% [markdown]
# #Для всех групп в дата фрейме

# %%
df1.groupby('CountryCode').sum()['Population']
# Out:
# CountryCode
# ABW       29034
# AFG     2332100
# AGO     2561600
# AIA        1556
# ALB      270000
#          ...
# YEM     1743700
# YUG     2189507
# ZAF    15196370
# ZMB     2473500
# ZWE     2730420
# Name: Population, Length: 232, dtype: int64

# %%
df1.groupby(['CountryCode']).agg(['min', 'max', 'mean', 'count'])['Population'].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df1.groupby(['CountryCode']).agg(['min', 'max', 'mean', 'count'])['Population'].head()
#
# NameError: name 'df1' is not defined

# %%
df1.groupby(['CountryCode']).agg(['min', 'max', 'mean', 'count'])['Population'].reset_index().head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df1.groupby(['CountryCode']).agg(['min', 'max', 'mean', 'count'])['Population'].reset_index().head()
#
# NameError: name 'df1' is not defined

# %%
code_group = df1.groupby('CountryCode')
code_group

# %%
# for index, value in code_group:
#     print(index)
#     print(value)

# %%
code_group.get_group('AFG')
# Out:
#    ID            Name CountryCode  District  Population
# 0   1           Kabul         AFG     Kabol     1780000
# 1   2        Qandahar         AFG  Qandahar      237500
# 2   3           Herat         AFG     Herat      186800
# 3   4  Mazar-e-Sharif         AFG     Balkh      127800

# %% [markdown]
# ##Statistic

# %%
code_group.describe()
# Out:
#                ID                                                       \
#             count    mean        std     min      25%     50%      75%
# CountryCode
# ABW           1.0   129.0        NaN   129.0   129.00   129.0   129.00
# AFG           4.0     2.5   1.290994     1.0     1.75     2.5     3.25
# AGO           5.0    58.0   1.581139    56.0    57.00    58.0    59.00
# AIA           2.0    61.5   0.707107    61.0    61.25    61.5    61.75
# ALB           1.0    34.0        NaN    34.0    34.00    34.0    34.00
# ...           ...     ...        ...     ...      ...     ...      ...
# YEM           6.0  1782.5   1.870829  1780.0  1781.25  1782.5  1783.75
# YUG           8.0  1795.5   2.449490  1792.0  1793.75  1795.5  1797.25
# ZAF          44.0   733.5  12.845233   712.0   722.75   733.5   744.25
# ZMB           7.0  3165.0   2.160247  3162.0  3163.50  3165.0  3166.50
# ZWE           6.0  4070.5   1.870829  4068.0  4069.25  4070.5  4071.75
#
# ...

# %%
code_group.describe()['Population']
# Out:
#              count           mean            std       min        25%  \
# CountryCode
# ABW            1.0   29034.000000            NaN   29034.0   29034.00
# AFG            4.0  583025.000000  799241.458614  127800.0  172050.00
# AGO            5.0  512320.000000  844105.862437  118200.0  128300.00
# AIA            2.0     778.000000     258.801082     595.0     686.50
# ALB            1.0  270000.000000            NaN  270000.0  270000.00
# ...            ...            ...            ...       ...        ...
# YEM            6.0  290616.666667  155648.468244  103300.0  166425.00
# YUG            8.0  273688.375000  377226.883552   92303.0  126346.50
# ZAF           44.0  345372.045455  366793.373731   89292.0  166479.00
# ZMB            7.0  353357.142857  433110.412625  118100.0  133150.00
# ZWE            6.0  455070.000000  503661.219871  128037.0  139615.75
#
#                   50%        75%        max
# CountryCode
# ABW           29034.0   29034.00    29034.0
# ...
