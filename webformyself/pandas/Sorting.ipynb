# %%
import pandas as pd

# %%
df = pd.read_csv("D:/PythonProject/webformyself/city.csv", sep=';')
df
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
df.sort_values(by='Population', ascending=False)
# Out:
#         ID                Name CountryCode      District  Population
# 1023  1024     Mumbai (Bombay)         IND   Maharashtra    10500000
# 2330  2331               Seoul         KOR         Seoul     9981619
# 205    206           São Paulo         BRA     São Paulo     9968485
# 1889  1890            Shanghai         CHN      Shanghai     9696300
# 938    939             Jakarta         IDN  Jakarta Raya     9604900
# ...    ...                 ...         ...           ...         ...
# 2315  2316              Bantam         CCK   Home Island         503
# 3537  3538  Città del Vaticano         VAT             –         455
# 3332  3333             Fakaofo         TKL       Fakaofo         300
# 2316  2317         West Island         CCK   West Island         167
# 2911  2912           Adamstown         PCN             –          42
#
# [4079 rows x 5 columns]

# %%
df2 = pd.read_csv("D:/PythonProject/webformyself/country.csv", sep=';')
df2
# Out:
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# 235  YUG    Yugoslavia         Europe            Southern Europe     102173.0
# 236  ZAF  South Africa         Africa            Southern Africa    1221037.0
# 237  ZMB        Zambia         Africa             Eastern Africa     752618.0
# 238  ZWE      Zimbabwe         Africa             Eastern Africa     390757.0
#
# ...

# %%
df2.sort_values(by='GNPOld', na_position='first')
# Out:
#     Code                  Name      Continent                     Region  \
# 1    AFG           Afghanistan           Asia  Southern and Central Asia
# 3    AIA              Anguilla  North America                  Caribbean
# 5    AND               Andorra         Europe            Southern Europe
# 6    ANT  Netherlands Antilles  North America                  Caribbean
# 10   ASM        American Samoa        Oceania                  Polynesia
# ..   ...                   ...            ...                        ...
# 76   GBR        United Kingdom         Europe            British Islands
# 72   FRA                France         Europe             Western Europe
# 56   DEU               Germany         Europe             Western Europe
# 109  JPN                 Japan           Asia               Eastern Asia
# 223  USA         United States  North America              North America
#
#      SurfaceArea  IndepYear  Population  LifeExpectancy        GNP     GNPOld  \
# ...

# %%
# df.sort_values(by='Population', ascending=False, ignore_index=True)
df.sort_values(by='Population', ascending=False).reset_index()
# Out:
#       index    ID                Name CountryCode      District  Population
# 0      1023  1024     Mumbai (Bombay)         IND   Maharashtra    10500000
# 1      2330  2331               Seoul         KOR         Seoul     9981619
# 2       205   206           São Paulo         BRA     São Paulo     9968485
# 3      1889  1890            Shanghai         CHN      Shanghai     9696300
# 4       938   939             Jakarta         IDN  Jakarta Raya     9604900
# ...     ...   ...                 ...         ...           ...         ...
# 4074   2315  2316              Bantam         CCK   Home Island         503
# 4075   3537  3538  Città del Vaticano         VAT             –         455
# 4076   3332  3333             Fakaofo         TKL       Fakaofo         300
# 4077   2316  2317         West Island         CCK   West Island         167
# 4078   2911  2912           Adamstown         PCN             –          42
#
# [4079 rows x 6 columns]

# %%
df.sort_values(by=['CountryCode', 'Name'], ascending=True)
# Out:
#         ID            Name CountryCode    District  Population
# 128    129      Oranjestad         ABW           –       29034
# 2        3           Herat         AFG       Herat      186800
# 0        1           Kabul         AFG       Kabol     1780000
# 3        4  Mazar-e-Sharif         AFG       Balkh      127800
# 1        2        Qandahar         AFG    Qandahar      237500
# ...    ...             ...         ...         ...         ...
# 4069  4070     Chitungwiza         ZWE      Harare      274912
# 4072  4073           Gweru         ZWE    Midlands      128037
# 4067  4068          Harare         ZWE      Harare     1410000
# 4070  4071    Mount Darwin         ZWE      Harare      164362
# 4071  4072          Mutare         ZWE  Manicaland      131367
#
# [4079 rows x 5 columns]

# %%
# df.groupby('CountryCode')[['Population']].max().sort_values('Population', ascending=False)
df.groupby('CountryCode')['Population'].max().to_frame().sort_values('Population', ascending=False).head(7)
# Out:
#              Population
# CountryCode
# IND            10500000
# KOR             9981619
# BRA             9968485
# CHN             9696300
# IDN             9604900
# PAK             9269265
# TUR             8787958
