# %%
import pandas as pd

# %%
pip install XlsxWriter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# df = pd.read_csv("D:\PythonProject\webformyself\city.csv", sep=';', nrows=100)
df = pd.read_csv("D:\PythonProject\webformyself\city.csv", sep=';')
df
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Yevheniia\AppData\Local\Temp\ipykernel_14912\2310754500.py:2: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv("D:\PythonProject\webformyself\city.csv", sep=';')
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# ...

# %%
df['Location'] = df.Name + ', ' + df.CountryCode
df
# Out:
#         ID            Name CountryCode       District  Population  \
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
#                  Location
# 0              Kabul, AFG
# 1           Qandahar, AFG
# 2              Herat, AFG
# 3     Mazar-e-Sharif, AFG
# 4          Amsterdam, NLD
# ...

# %%
# df.to_csv('city3.csv', sep = ',')
df.to_csv('city3.csv', sep = ',', columns=['ID', 'Location', 'Population'])

# %%
import pandas as pd

# %% [markdown]
# EXCEL FILES

# %%
df2= pd.read_excel("D:/PythonProject/webformyself/cities.xlsx", sheet_name=0)
df2
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
def convert_population(value):
    return '{:,}'.format(value)

# def convert_population2(value):
#     if value>100000:
#         return '{:,}'.format(value)
#     return value
    
df2= pd.read_excel("D:/PythonProject/webformyself/cities.xlsx", sheet_name=0, converters={'Population': convert_population})
df2
# соблюдать осторожность с конвертированием, т.к. переводим цифры в строки
# Out:
#         ID            Name CountryCode       District Population
# 0        1           Kabul         AFG          Kabol  1,780,000
# 1        2        Qandahar         AFG       Qandahar    237,500
# 2        3           Herat         AFG          Herat    186,800
# 3        4  Mazar-e-Sharif         AFG          Balkh    127,800
# 4        5       Amsterdam         NLD  Noord-Holland    731,200
# ...    ...             ...         ...            ...        ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis    123,175
# 4075  4076          Hebron         PSE         Hebron    119,401
# 4076  4077        Jabaliya         PSE     North Gaza    113,901
# 4077  4078          Nablus         PSE         Nablus    100,231
# 4078  4079           Rafah         PSE          Rafah     92,020
#
# [4079 rows x 5 columns]

# %%
df2.to_excel('cities3.xlsx', sheet_name='FormattedCities', index=False)

# %%
df3= pd.read_excel("D:/PythonProject/webformyself/cities.xlsx", sheet_name=1)
df3
# Out:
#    № п/п Фамилия   Имя Дата рождения
# 0      1  Иванов  Иван    2000-01-31
# 1      2  Петров  Петр    2001-11-10

# %%
with pd.ExcelWriter('cities3.xlsx') as writer:
    df2.to_excel(writer, sheet_name='FormattedCities', index=False)
    df3.to_excel(writer, sheet_name='Names', index=False)

# %% [markdown]
# ПЕРЕИМЕНОВАТЬ КОЛОНКИ В ВЕРХНИЙ РЕГИСТР

# %%
df= pd.read_excel("D:/PythonProject/webformyself/cities.xlsx", sheet_name=0)
df
df.rename(str.upper, axis = 1, inplace=True)
# Out:
#         ID            NAME COUNTRYCODE       DISTRICT  POPULATION
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %% [markdown]
# ПРОВЕРКА НА ОТСУТСТВУЮЩИЕ ЗНАЧЕНИЯ

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4079 entries, 0 to 4078
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           4079 non-null   int64
#  1   Name         4079 non-null   object
#  2   CountryCode  4079 non-null   object
#  3   District     4075 non-null   object
#  4   Population   4079 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 159.5+ KB

# %%
df[df.District.isna()]
# Out:
#         ID           Name CountryCode District  Population
# 3284  3285        Taiping         TWN      NaN      165524
# 3292  3293         Taliao         TWN      NaN      115897
# 3293  3294       Kueishan         TWN      NaN      112195
# 3562  3563  Ciudad Losada         VEN      NaN      134501

# %% [markdown]
# УДАЛИТЬ ИЗ ДАТА ФРЕЙМА СТРОКИ С ОТСУТСТВУЮЩИМИ ЗНАЧЕНИЯМИ

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4075 entries, 0 to 4078
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           4075 non-null   int64
#  1   Name         4075 non-null   object
#  2   CountryCode  4075 non-null   object
#  3   District     4075 non-null   object
#  4   Population   4075 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 191.0+ KB

# %% [markdown]
# ВЫНЕСТИ В НОВЫЙ ДАТАФРЕЙМ ДАННЫЕ С > 1млн ЧЕЛ

# %%
df4 = df[df.Population > 1000000]
df4
# Out:
#         ID          Name CountryCode          District  Population
# 0        1         Kabul         AFG             Kabol     1780000
# 34      35         Alger         DZA             Alger     2168000
# 55      56        Luanda         AGO            Luanda     2022000
# 68      69  Buenos Aires         ARG  Distrito Federal     2982146
# 69      70    La Matanza         ARG      Buenos Aires     1266461
# ...    ...           ...         ...               ...         ...
# 3797  3798       Phoenix         USA           Arizona     1321045
# 3798  3799     San Diego         USA        California     1223400
# 3799  3800        Dallas         USA             Texas     1188580
# 3800  3801   San Antonio         USA             Texas     1144646
# 4067  4068        Harare         ZWE            Harare     1410000
#
# [237 rows x 5 columns]

# %% [markdown]
# УДАЛИТЬ СТОЛБЕЦ DISTRICT

# %%
df.drop('District', axis=1)
# Out:
#         ID            Name CountryCode  Population
# 0        1           Kabul         AFG     1780000
# 1        2        Qandahar         AFG      237500
# 2        3           Herat         AFG      186800
# 3        4  Mazar-e-Sharif         AFG      127800
# 4        5       Amsterdam         NLD      731200
# ...    ...             ...         ...         ...
# 4074  4075      Khan Yunis         PSE      123175
# 4075  4076          Hebron         PSE      119401
# 4076  4077        Jabaliya         PSE      113901
# 4077  4078          Nablus         PSE      100231
# 4078  4079           Rafah         PSE       92020
#
# [4075 rows x 4 columns]

# %% [markdown]
# ЗАПИСАТЬ датафрейм В ФАЙЛ test.xlsx БЕЗ СОХРАНЕНИЯ ИНДЕКСА

# %%
df.to_excel('test.xlsx', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4075 entries, 0 to 4078
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           4075 non-null   int64
#  1   Name         4075 non-null   object
#  2   CountryCode  4075 non-null   object
#  3   District     4075 non-null   object
#  4   Population   4075 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 191.0+ KB

# %%
df.shape
# Out:
# (4075, 5)

# %%
len(df)
# Out:
# 4075
