# %%
import pandas as pd

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('XFkglYw8FbU', 800, 500)

# %%
from IPython.display import IFrame
IFrame('https://www.youtube.com/watch?v=XFkglYw8FbU', 800, 500)
# Out:
#         <iframe
#             width="800"
#             height="500"
#             src="https://www.youtube.com/watch?v=XFkglYw8FbU"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
